# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Question Set 1
#
# Using your store items data:

# %%
import pandas as pd
import matplotlib.pyplot as plt

from acquire import get_total_sales_by_stores_data, get_germany_power_data
from prepare import prepare_store_data, prepare_power_data

# %%
df = get_total_sales_by_stores_data()

# %%
df.head()
# Out:
#    sale_amount                      sale_date  sale_id  \
# 0         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1
# 1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2
# 2         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3
# 3         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4
# 4         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5
#
#             store_address   store_city  store_id store_state  store_zipcode  \
# 0  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 1  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 2  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 3  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 4  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
#
#   item_brand  item_id                       item_name  item_price  \
# 0   Riceland        1  Riceland American Jazmine Rice        0.84
# ...

# %% [markdown]
# ### Exercise 1
# Convert date column to datetime format.

# %%
from time import strftime

# %%
df.sale_date = pd.to_datetime(df.sale_date, format='%a, %d %b %Y %H:%M:%S %Z')

# %%
df.head()
# Out:
#    sale_amount                 sale_date  sale_id           store_address  \
# 0         13.0 2013-01-01 00:00:00+00:00        1  12125 Alamo Ranch Pkwy
# 1         11.0 2013-01-02 00:00:00+00:00        2  12125 Alamo Ranch Pkwy
# 2         14.0 2013-01-03 00:00:00+00:00        3  12125 Alamo Ranch Pkwy
# 3         13.0 2013-01-04 00:00:00+00:00        4  12125 Alamo Ranch Pkwy
# 4         10.0 2013-01-05 00:00:00+00:00        5  12125 Alamo Ranch Pkwy
#
#     store_city  store_id store_state  store_zipcode item_brand  item_id  \
# 0  San Antonio         1          TX          78253   Riceland        1
# 1  San Antonio         1          TX          78253   Riceland        1
# 2  San Antonio         1          TX          78253   Riceland        1
# 3  San Antonio         1          TX          78253   Riceland        1
# 4  San Antonio         1          TX          78253   Riceland        1
#
#                         item_name  item_price   item_upc12   item_upc14
# ...

# %% [markdown]
# ### Exercise 2
# Plot the distribution of sale_amount and item_price.

# %%
df.sale_amount.plot.hist()
plt.title('Distribution for Total Items Sold')
plt.xlabel('Total Items Sold')
plt.show()

# %%
df.item_price.plot.hist()
plt.title('Distribution for Item Price')
plt.xlabel('Item Price')
plt.show()

# %% [markdown]
# ### Exercise 3
# Set the index to be the datetime variable.

# %%
df = df.set_index("sale_date").sort_index()

# %%
df.head()
# Out:
#                            sale_amount  sale_id           store_address  \
# sale_date
# 2013-01-01 00:00:00+00:00         13.0        1  12125 Alamo Ranch Pkwy
# 2013-01-01 00:00:00+00:00         26.0   211817  12018 Perrin Beitel Rd
# 2013-01-01 00:00:00+00:00         27.0   832657  12018 Perrin Beitel Rd
# 2013-01-01 00:00:00+00:00         54.0   213643     15000 San Pedro Ave
# 2013-01-01 00:00:00+00:00         35.0   215469      735 SW Military Dr
#
#                             store_city  store_id store_state  store_zipcode  \
# sale_date
# 2013-01-01 00:00:00+00:00  San Antonio         1          TX          78253
# 2013-01-01 00:00:00+00:00  San Antonio         7          TX          78217
# 2013-01-01 00:00:00+00:00  San Antonio         7          TX          78217
# 2013-01-01 00:00:00+00:00  San Antonio         8          TX          78232
# 2013-01-01 00:00:00+00:00  San Antonio         9          TX          78221
#
#                            item_brand  item_id  \
# ...

# %% [markdown]
# ### Exercise 4
# Add a 'month' and 'day of week' column to your dataframe.

# %%
df['month'] = df.index.month

# %%
df['day_of_the_week'] = df.index.day_name()

# %%
df
# Out:
#                            sale_amount  sale_id           store_address  \
# sale_date
# 2013-01-01 00:00:00+00:00         13.0        1  12125 Alamo Ranch Pkwy
# 2013-01-01 00:00:00+00:00         26.0   211817  12018 Perrin Beitel Rd
# 2013-01-01 00:00:00+00:00         27.0   832657  12018 Perrin Beitel Rd
# 2013-01-01 00:00:00+00:00         54.0   213643     15000 San Pedro Ave
# 2013-01-01 00:00:00+00:00         35.0   215469      735 SW Military Dr
# ...                                ...      ...                     ...
# 2017-12-31 00:00:00+00:00         21.0   619014      735 SW Military Dr
# 2017-12-31 00:00:00+00:00         32.0   620840    8503 NW Military Hwy
# 2017-12-31 00:00:00+00:00         55.0   622666  12125 Alamo Ranch Pkwy
# 2017-12-31 00:00:00+00:00        100.0   598928     15000 San Pedro Ave
# 2017-12-31 00:00:00+00:00         82.0   913000    8503 NW Military Hwy
#
#                             store_city  store_id store_state  store_zipcode  \
# sale_date
# ...

# %% [markdown]
# ### Exercise 5
# Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.

# %%
df['sales_total'] = df.sale_amount * df.item_price

# %%
df
# Out:
#                            sale_amount  sale_id           store_address  \
# sale_date
# 2013-01-01 00:00:00+00:00         13.0        1  12125 Alamo Ranch Pkwy
# 2013-01-01 00:00:00+00:00         26.0   211817  12018 Perrin Beitel Rd
# 2013-01-01 00:00:00+00:00         27.0   832657  12018 Perrin Beitel Rd
# 2013-01-01 00:00:00+00:00         54.0   213643     15000 San Pedro Ave
# 2013-01-01 00:00:00+00:00         35.0   215469      735 SW Military Dr
# ...                                ...      ...                     ...
# 2017-12-31 00:00:00+00:00         21.0   619014      735 SW Military Dr
# 2017-12-31 00:00:00+00:00         32.0   620840    8503 NW Military Hwy
# 2017-12-31 00:00:00+00:00         55.0   622666  12125 Alamo Ranch Pkwy
# 2017-12-31 00:00:00+00:00        100.0   598928     15000 San Pedro Ave
# 2017-12-31 00:00:00+00:00         82.0   913000    8503 NW Military Hwy
#
#                             store_city  store_id store_state  store_zipcode  \
# sale_date
# ...

# %% [markdown]
# ### Exercise 6
# Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
stores = prepare_store_data()

# %% [markdown]
# ## Question Set 2
#
# Using the OPS data acquired in the Acquire exercises opsd_germany_daily.csv, complete the following:

# %%
power = get_germany_power_data()
power.head()
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN

# %% [markdown]
# ### Exercise 1
# Convert date column to datetime format.

# %%
power.Date = pd.to_datetime(power.Date, format='%Y %m %d')

# %%
power.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         4383 non-null   datetime64[ns]
#  1   Consumption  4383 non-null   float64
#  2   Wind         2920 non-null   float64
#  3   Solar        2188 non-null   float64
#  4   Wind+Solar   2187 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 171.3 KB

# %%
power.head()
# Out:
#         Date  Consumption  Wind  Solar  Wind+Solar
# 0 2006-01-01     1069.184   NaN    NaN         NaN
# 1 2006-01-02     1380.521   NaN    NaN         NaN
# 2 2006-01-03     1442.533   NaN    NaN         NaN
# 3 2006-01-04     1457.217   NaN    NaN         NaN
# 4 2006-01-05     1477.131   NaN    NaN         NaN

# %% [markdown]
# ### Exercise 2
# Plot the distribution of each of your variables.

# %%
power.Consumption.plot.hist()
plt.title('Distribution for Consumption')
plt.xlabel('Consumption')
plt.show()

# %%
power.Wind.plot.hist()
plt.title('Distribution for Wind')
plt.xlabel('Wind')
plt.show()

# %%
power.Solar.plot.hist()
plt.title('Distribution for Solar')
plt.xlabel('Solar')
plt.show()

# %%
power['Wind+Solar'].plot.hist()
plt.title('Distribution for Wind+Solar')
plt.xlabel('Wind+Solar')
plt.show()

# %% [markdown]
# ### Exercise 3
# Set the index to be the datetime variable.

# %%
power = power.set_index("Date").sort_index()

# %%
power.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN
# 2006-01-02     1380.521   NaN    NaN         NaN
# 2006-01-03     1442.533   NaN    NaN         NaN
# 2006-01-04     1457.217   NaN    NaN         NaN
# 2006-01-05     1477.131   NaN    NaN         NaN

# %% [markdown]
# ### Exercise 4
# Add a month and a year column to your dataframe.

# %%
power['month'] = power.index.month

# %%
power['year'] = power.index.year

# %% [markdown]
# ### Exercise 5
# Fill any missing values.

# %%
power = power.fillna(0)

# %% [markdown]
# ### Exercise 6
# Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
germany = prepare_power_data()

# %%
germany.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar  month  year
# Date
# 2006-01-01     1069.184   0.0    0.0         0.0      1  2006
# 2006-01-02     1380.521   0.0    0.0         0.0      1  2006
# 2006-01-03     1442.533   0.0    0.0         0.0      1  2006
# 2006-01-04     1457.217   0.0    0.0         0.0      1  2006
# 2006-01-05     1477.131   0.0    0.0         0.0      1  2006
